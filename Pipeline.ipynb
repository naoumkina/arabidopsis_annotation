# %% [markdown]
# # NCBI Annotation Pipeline
#
# 1. Create and activate the conda environment. Why this matters?
# A dedicated environment ensures reproducibility and prevents conflicts with system Python or cluster modules.
# 2. Organaze files in project directory
# 3. Run the annotation script

# %%
# !python annotate_arabidopsis_from_ncbi.py
# Out:
# [1/212] Processing AT5G54510...
# [2/212] Processing AT1G76180...
# [3/212] Processing AT5G43020...
# [4/212] Processing AT2G41550...
# [5/212] Processing AT2G02070...
# [6/212] Processing AT2G01610...
# [7/212] Processing AT3G61470...
# [8/212] Processing AT4G38580...
# [9/212] Processing AT3G56880...
# [10/212] Processing AT5G04140...
# [11/212] Processing AT4G13590...
# [12/212] Processing AT1G09750...
# [13/212] Processing AT3G16240...
# [14/212] Processing AT4G39830...
# [15/212] Processing AT5G41410...
# [16/212] Processing AT2G27080...
# [17/212] Processing AT3G45640...
# [18/212] Processing AT1G69780...
# [19/212] Processing AT2G03440...
# [20/212] Processing AT1G71110...
# [21/212] Processing AT1G23740...
# [22/212] Processing AT1G27100...
# [23/212] Processing AT3G21870...
# [24/212] Processing AT5G23440...
# [25/212] Processing AT2G14960...
# [26/212] Processing AT2G15020...
# [27/212] Processing AT4G28080...
# [28/212] Processing AT2G37170...
# ...

# %% [markdown]
# ## Preview the result

# %%
import pandas as pd

df = pd.read_csv("results/ncbi_annotation_for_arabidopsis_genes.csv")
df.head()
# Out:
#          AGI  NCBI_GeneID     Symbol  \
# 0  AT5G54510       835539       DFL1
# 1  AT1G76180       843950      ERD14
# 2  AT5G43020       834317  AT5G43020
# 3  AT2G41550       818753  AT2G41550
# 4  AT2G02070       814738       IDD5
#
#                                          Description  \
# 0                Auxin-responsive GH3 family protein
# 1                            Dehydrin family protein
# 2  Leucine-rich repeat protein kinase family protein
# 3                             Rho termination factor
# 4                         indeterminate(ID)-domain 5
#
#                                              Summary  GO_Terms  \
# 0  Encodes an IAA-amido synthase that conjugates ...       NaN
# 1  Encodes a dehydrin protein whose expression is...       NaN
# 2                                                NaN       NaN
# 3                                                NaN       NaN
# 4                                                NaN       NaN
#
# ...
